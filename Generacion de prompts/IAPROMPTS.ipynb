# %%
# Importar las bibliotecas necesarias
import openai
import os

# Configurar la clave API de OpenAI
openai.api_key = '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'

# %%
# Prompts para identificar necesidades del usuario
prompts_identificacion = [
    "¿Cuál es tu objetivo principal en términos de desarrollo muscular?",
    "¿Cuánto tiempo puedes dedicar al entrenamiento semanalmente?",
    "¿Tienes alguna restricción dietética o condición médica?"
]

# Prompts para recomendaciones de entrenamiento
prompts_entrenamiento = [
    "Proporcióname una rutina de entrenamiento efectiva para aumentar masa muscular en un período de 3 meses.",
    "¿Cuáles son los ejercicios más efectivos para desarrollar el pecho y los tríceps?"
]

# Prompts para planificación nutricional
prompts_nutricion = [
    "Desarrolla un plan de alimentación diario que incluya 3000 calorías enfocadas en el crecimiento muscular.",
    "¿Qué suplementos son recomendables para mejorar el rendimiento en el gimnasio?"
]

# Prompt para monitoreo y ajustes
prompts_monitoreo = "¿Cuáles son los cambios recomendados en mi rutina si no estoy viendo resultados en 4 semanas?"

# %%
# Función para realizar una consulta a la API de OpenAI utilizando gpt-3.5-turbo
def consulta_openai(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Eres un asistente experto que ayuda a planificar rutinas de entrenamiento y nutrición."},
            {"role": "user", "content": prompt}
        ]
    )
    return response['choices'][0]['message']['content'].strip()

# Ejemplo de uso
respuesta = consulta_openai(prompts_identificacion[0])
print(respuesta)
# Out:
# Mi objetivo principal en términos de desarrollo muscular es ayudarte a diseñar un plan de entrenamiento y nutrición efectivo y personalizado que te ayude a aumentar tu masa muscular de manera segura y sostenible. Quiero asegurarme de que tengas la información y las herramientas necesarias para alcanzar tus metas de forma saludable y sin riesgos. ¿Cómo puedo ayudarte con tu objetivo de desarrollo muscular?

# %%
# Prueba de prompt para recomendaciones de entrenamiento
for prompt in prompts_entrenamiento:
    respuesta = consulta_openai(prompt)
    print(f"Prompt: {prompt}")
    print(f"Respuesta: {respuesta}\n")

# Prueba de prompt para planificación nutricional
for prompt in prompts_nutricion:
    respuesta = consulta_openai(prompt)
    print(f"Prompt: {prompt}")
    print(f"Respuesta: {respuesta}\n")
# Out:
# Prompt: Proporcióname una rutina de entrenamiento efectiva para aumentar masa muscular en un período de 3 meses.
# Respuesta: Aquí te dejo una rutina de entrenamiento para aumentar masa muscular en un período de 3 meses. Es importante recordar que la clave para lograr resultados efectivos es mantener la constancia, la intensidad y la progresión en tus entrenamientos, además de acompañarlos con una alimentación adecuada.
#
# Días de entrenamiento: 4 días a la semana (por ejemplo, lunes, martes, jueves y viernes)
#
# **Día 1 - Entrenamiento de tren superior:**
# 1. Press de banca: 4 series de 8-10 repeticiones
# 2. Dominadas: 4 series de 8-10 repeticiones
# 3. Press militar: 3 series de 10-12 repeticiones
# 4. Elevaciones laterales: 3 series de 12-15 repeticiones
# 5. Curl de bíceps con barra: 3 series de 10-12 repeticiones
# 6. Tríceps en polea: 3 series de 10-12 repeticiones
#
# **Día 2 - Entrenamiento de tren inferior:**
# 1. Sentadillas: 4 series de 8-10 repeticiones
# 2. Prensa de piernas: 3 series de 10-12 repeticiones
# 3. Peso muerto: 4 series de 8-10 repeticiones
# 4. Extensiones de cuádriceps: 3 series de 12-15 repeticiones
# 5. Curl de piernas acostado: 3 series de 10-12 repeticiones
# 6. Elevación de talones de pie: 3 series de 12-15 repeticiones
#
# **Día 3 - Descanso**
#
# **Día 4 - Entrenamiento de tren superior:**
# 1. Press de hombros con mancuernas: 4 series de 8-10 repeticiones
# 2. Fondos en paralelas: 4 series de 8-10 repeticiones
# 3. Remo con barra: 3 series de 10-12 repeticiones
# 4. Aperturas con mancuernas: 3 series de 12-15 repeticiones
# 5. Curl de bíceps martillo: 3 series de 10-12 repeticiones
# 6. Extensiones de tríceps en cuerda: 3 series de 10-12 repeticiones
#
# **Día 5 - Entrenamiento de tren inferior:**
# 1. Zancadas: 4 series de 8-10 repeticiones por pierna
# 2. Prensa inclinada de piernas: 3 series de 10-12 repeticiones
# 3. Peso muerto rumano: 4 series de 8-10 repeticiones
# 4. Elevaciones de talones sentado: 3 series de 12-15 repeticiones
# 5. Curl femoral tumbado: 3 series de 10-12 repeticiones
# 6. Abductores en máquina: 3 series de 12-15 repeticiones
#
# Recuerda realizar un calentamiento antes de cada sesión de entrenamiento, y estirar al finalizar para mantener la flexibilidad muscular y prevenir lesiones.
#
# Además, es importante acompañar este plan de entrenamiento con una alimentación adecuada, que incluya una cantidad suficiente de proteínas, carbohidratos y grasas saludables para satisfacer tus necesidades energéticas y de recuperación muscular. ¡Buena suerte con tu entrenamiento!
#
# Prompt: ¿Cuáles son los ejercicios más efectivos para desarrollar el pecho y los tríceps?
# Respuesta: Para desarrollar el pecho de manera efectiva, te recomendaría incluir los siguientes ejercicios en tu rutina de entrenamiento:
# 1. Press de banca: Es uno de los ejercicios más efectivos para trabajar el pecho y también involucra los tríceps y los hombros.
# 2. Fondos en paralelas: Excelente ejercicio para trabajar los músculos del pecho, especialmente el músculo pectoral mayor.
# 3. Aperturas con mancuernas: Ideal para aislar el músculo pectoral y trabajar la parte externa del pecho.
#
# Para desarrollar los tríceps, puedes incorporar los siguientes ejercicios en tu rutina:
# 1. Press de banca con agarre cerrado: Enfocado en los tríceps, este ejercicio ayuda a desarrollar la porción larga de este músculo.
# 2. Fondos en paralelas con agarre cerrado: Excelente para aislar y trabajar los tríceps.
# 3. Extensiones de tríceps con polea o mancuernas: Concentra el esfuerzo en los tríceps y ayuda a desarrollar fuerza y tamaño en estos músculos.
#
# Recuerda mantener una buena técnica al realizar cada ejercicio, variar tu rutina periódicamente y asegurarte de darle suficiente descanso a tus músculos para permitir su recuperación y crecimiento.
#
# Prompt: Desarrolla un plan de alimentación diario que incluya 3000 calorías enfocadas en el crecimiento muscular.
# Respuesta: Aquí tienes un ejemplo de plan de alimentación diario de 3000 calorías enfocado en el crecimiento muscular:
#
# Desayuno:
# - 100g de avena cocida con 1 plátano en rodajas y 30g de almendras fileteadas.
# - 2 huevos revueltos con espinacas y tomate.
# - 1 vaso de leche desnatada.
#
# Media mañana:
# - 1 batido de proteínas con 1 plátano y 30g de avena.
#
# Almuerzo:
# - 150g de pechuga de pollo a la parrilla.
# - 200g de quinoa cocida.
# - Ensalada de espinacas, tomate, pepino y aguacate aliñada con aceite de oliva.
#
# Merienda:
# - 1 yogur griego natural con 30g de nueces.
#
# Cena:
# - 150g de salmón a la plancha.
# - 150g de arroz integral cocido.
# - Espárragos al vapor con limón.
#
# Antes de dormir:
# - 1 batido de caseína con agua.
#
# Recuerda que este es solo un ejemplo y puedes adaptar las comidas a tus preferencias y necesidades individuales. También es importante mantenerse bien hidratado a lo largo del día, bebiendo suficiente agua. Además, es recomendable consultar con un nutricionista o dietista para ajustar el plan a tus objetivos específicos y necesidades nutricionales.
#
# Prompt: ¿Qué suplementos son recomendables para mejorar el rendimiento en el gimnasio?
# Respuesta: Algunos suplementos recomendados para mejorar el rendimiento en el gimnasio son:
#
# 1. Proteína en polvo: Ayuda a aumentar la ingesta de proteínas necesaria para la recuperación muscular y el crecimiento.
#
# 2. BCAA (aminoácidos de cadena ramificada): Ayudan a prevenir la degradación muscular durante el ejercicio intenso y promueven la recuperación muscular.
#
# 3. Creatina: Ayuda a mejorar la fuerza y el rendimiento en entrenamientos de alta intensidad.
#
# 4. Cafeína: Puede aumentar la energía, la concentración y la resistencia durante el ejercicio.
#
# Es importante recordar que los suplementos son solo eso, complementos a una dieta y entrenamiento adecuados. Se recomienda consultar con un profesional de la salud o un nutricionista antes de comenzar a tomar cualquier suplemento.

# %%
def consulta_openai(prompt):
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "Eres un asistente que ayuda a planificar rutinas de entrenamiento y nutrición."},
                {"role": "user", "content": prompt}
            ]
        )
        return response['choices'][0]['message']['content'].strip()
    except openai.error.OpenAIError as e:
        print(f"Error al realizar la consulta: {e}")
        return None

# Función para capturar la pregunta del usuario y obtener una respuesta
def interactuar_con_usuario():
    # Capturar la pregunta del usuario
    pregunta_usuario = input("Por favor, ingresa tu pregunta: ")
    
    # Obtener la respuesta del modelo de IA
    respuesta = consulta_openai(pregunta_usuario)
    
    # Verificar si se recibió una respuesta
    if respuesta:
        print(f"Respuesta: {respuesta}")
    else:
        print("No se pudo obtener una respuesta.")

# Llamada a la función para interactuar con el usuario
interactuar_con_usuario()
# Out:
# Por favor, ingresa tu pregunta:  ¿si yo mido 1.50 y tengo 50 kilos que comida me ayudara a crecer?
# Respuesta: Para crecer de estatura, es importante mantener una dieta balanceada que incluya los nutrientes necesarios para el crecimiento. Algunos alimentos que podrían ser beneficiosos para ayudarte a crecer son:
#
# 1. Proteínas: Las proteínas son necesarias para el crecimiento y el desarrollo muscular. Puedes obtener proteínas de fuentes como pollo, pescado, carne magra, legumbres, huevos y lácteos.
#
# 2. Calcio: El calcio es fundamental para el crecimiento de los huesos. Puedes obtener calcio de alimentos como la leche, el queso, el yogur, las espinacas, las almendras y el brócoli.
#
# 3. Vitamina D: La vitamina D es importante para la absorción del calcio. Puedes obtener vitamina D de alimentos como el salmón, el atún, la yema de huevo y a través de la exposición al sol.
#
# 4. Frutas y verduras: Es importante consumir una variedad de frutas y verduras para obtener vitaminas, minerales y antioxidantes que son esenciales para el crecimiento y la salud en general.
#
# Recuerda que el crecimiento es un proceso individual y en gran medida está determinado por la genética. Es importante mantener una dieta equilibrada y llevar un estilo de vida saludable que incluya ejercicio regular y suficiente descanso para favorecer el crecimiento. Si tienes alguna inquietud específica sobre tu dieta y necesidades nutricionales, te recomendaría consultar con un nutricionista para obtener una planificación personalizada.
